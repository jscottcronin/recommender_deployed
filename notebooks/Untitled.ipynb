# %% [markdown]
# # Purpose
# The purpose of this notebook is to generate an image for individual users in our recommender. The following API is used to collect images for users:
# https://randomuser.me/

# %%
import requests
import sklearn
import numpy as np
import json

# %% [markdown]
# First, let's pull 5000 generated users from the randomuser API

# %%
response = requests.get('https://randomuser.me/api/', params={'results': 5000})
results = response.json()['results']

print('Length of users generated: {}'.format(len(results)))
print('Example of user data:')
results[13]
# Out:
# Length of users generated: 5000
# Example of user data:
# {'cell': '(425)-398-7221',
#  'dob': '1957-07-31 21:21:57',
#  'email': 'alan.tucker@example.com',
#  'gender': 'male',
#  'id': {'name': 'SSN', 'value': '212-57-9624'},
#  'location': {'city': 'kansas city',
#   'postcode': 42168,
#   'state': 'nevada',
#   'street': '3890 edwards rd'},
#  'login': {'md5': '36310098957fa49c58c78d550a895f86',
#   'password': 'chipper',
#   'salt': 'X6WuEsjQ',
#   'sha1': '1b620f4b45a6182398d762752926e3ddbc3b0e09',
#   'sha256': '91e7588e6b6e84b35d42112b32dd31117db50fed4bb31238dd8297aadc17fd4f',
#   'username': 'browndog344'},
#  'name': {'first': 'alan', 'last': 'tucker', 'title': 'mr'},
#  'nat': 'US',
#  'phone': '(390)-100-1616',
#  'picture': {'large': 'https://randomuser.me/api/portraits/men/70.jpg',
#   'medium': 'https://randomuser.me/api/portraits/med/men/70.jpg',
#   'thumbnail': 'https://randomuser.me/api/portraits/thumb/men/70.jpg'},
#  'registered': '2006-05-26 21:05:40'}

# %% [markdown]
# Next, let's assign these random users to users in our recommender model

# %%
no_users = 69797
uidx = np.arange(no_users)
sample_uidx = map(str, np.random.choice(uidx, size=len(results), replace=False))
uidx_to_profile = dict(zip(sample_uidx, results))

# print key-value pair for 1 customer
customer = np.random.choice(list(uidx_to_profile))
uidx_to_profile[customer]
# Out:
# {'cell': '0948-750-0627',
#  'dob': '1959-07-14 04:17:21',
#  'email': 'مرسانا.کریمی@example.com',
#  'gender': 'female',
#  'id': {'name': '', 'value': None},
#  'location': {'city': 'تهران',
#   'postcode': 51837,
#   'state': 'خراسان شمالی',
#   'street': '1274 موسیوند'},
#  'login': {'md5': '28e1d8a09dc78cfd2796d67c32fea3e6',
#   'password': 'luck',
#   'salt': 'tszDlEP6',
#   'sha1': '783dc57efd3c361c92dcccaecb4032700d43a369',
#   'sha256': 'c72203679053ca2e26dac3dc2089e7e50dad5c42016c435a256d9317a7dff642',
#   'username': 'beautifulpeacock608'},
#  'name': {'first': 'مرسانا', 'last': 'کریمی', 'title': 'mrs'},
#  'nat': 'IR',
#  'phone': '059-15279693',
#  'picture': {'large': 'https://randomuser.me/api/portraits/women/28.jpg',
#   'medium': 'https://randomuser.me/api/portraits/med/women/28.jpg',
#   'thumbnail': 'https://randomuser.me/api/portraits/thumb/women/28.jpg'},
#  'registered': '2003-12-09 15:50:16'}

# %% [markdown]
# Store `user_to_profile` as a json file for use on webapp

# %%
with open('../app/objects/user_profiles.json', 'w') as f:
    json.dump(uidx_to_profile, f, sortindent=4)

# %%
uidx_to_profile[40812]
# Out:
# {'cell': '0744-261-346',
#  'dob': '1957-07-08 07:03:52',
#  'email': 'debra.bishop@example.com',
#  'gender': 'female',
#  'id': {'name': 'NINO', 'value': 'YM 38 28 93 B'},
#  'location': {'city': 'salisbury',
#   'postcode': 'RA80 3SL',
#   'state': 'durham',
#   'street': '6597 chester road'},
#  'login': {'md5': '3c1551375abc5031cdbf7595e0229354',
#   'password': '635241',
#   'salt': 'JPKcT9g4',
#   'sha1': '44cbcae7baa22d8a8878008c49d3272e4e0113ad',
#   'sha256': '256cae6e14fcbb1a169e671d833559e4e79b17a5b7bd49ad1f2da1ede4390a2a',
#   'username': 'smallcat121'},
#  'name': {'first': 'debra', 'last': 'bishop', 'title': 'ms'},
#  'nat': 'GB',
#  'phone': '013873 39188',
#  'picture': {'large': 'https://randomuser.me/api/portraits/women/15.jpg',
#   'medium': 'https://randomuser.me/api/portraits/med/women/15.jpg',
#   'thumbnail': 'https://randomuser.me/api/portraits/thumb/women/15.jpg'},
#  'registered': '2010-07-08 13:47:40'}

# %%
np.random.sample(list(uidx_to_profile.keys()), 10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-4d9d1e33db2b> in <module>()
# ----> 1 np.random.sample(list(uidx_to_profile.keys()), 10)
#
# mtrand.pyx in mtrand.RandomState.random_sample()
#
# TypeError: random_sample() takes at most 1 positional argument (2 given)

# %%
users = np.random.choice(list(uidx_to_profile), size=30, replace=False)
profiles = [(user, uidx_to_profile[user]) for user in users]

# %%
profiles
# Out:
# [('17760',
#   {'cell': '06-75-77-62-86',
#    'dob': '1947-04-11 10:18:40',
#    'email': 'mathilde.vidal@example.com',
#    'gender': 'female',
#    'id': {'name': 'INSEE', 'value': '247392690243 87'},
#    'location': {'city': 'limoges',
#     'postcode': 63365,
#     'state': 'alpes-de-haute-provence',
#     'street': '2404 avenue goerges clémenceau'},
#    'login': {'md5': '13fed990227ebceea6d437032301c179',
#     'password': 'nova',
#     'salt': 'zzDAbHod',
#     'sha1': '785da7101960807248f3a131155a3461fdd30126',
#     'sha256': '10ce03421b937784ba83f712bdd7ae7d644108986d6ad26d246404163f845420',
#     'username': 'smallgoose465'},
#    'name': {'first': 'mathilde', 'last': 'vidal', 'title': 'miss'},
#    'nat': 'FR',
#    'phone': '04-75-06-99-32',
#    'picture': {'large': 'https://randomuser.me/api/portraits/women/26.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/women/26.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/women/26.jpg'},
#    'registered': '2006-05-15 17:32:21'}),
#  ('7105',
#   {'cell': '0955-197-1682',
#    'dob': '1961-02-24 20:54:27',
#    'email': 'ستایش.سلطانینژاد@example.com',
#    'gender': 'female',
#    'id': {'name': '', 'value': None},
#    'location': {'city': 'قدس',
#     'postcode': 38319,
#     'state': 'بوشهر',
#     'street': '6837 استاد نجات\u200cاللهی'},
#    'login': {'md5': '04ddff224f7c23227550cef210f333b8',
#     'password': '2468',
#     'salt': 'hBU0WS47',
#     'sha1': '457d939a8789c8abf2327a8ff358065299d852ef',
#     'sha256': '00503cff8486a5bbb9f756fbd5bea04fe844dd64d5165b01aa0e73f990bbedd5',
#     'username': 'tinyfish110'},
#    'name': {'first': 'ستایش', 'last': 'سلطانی نژاد', 'title': 'ms'},
#    'nat': 'IR',
#    'phone': '026-90927241',
#    'picture': {'large': 'https://randomuser.me/api/portraits/women/9.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/women/9.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/women/9.jpg'},
#    'registered': '2016-03-23 21:36:33'}),
#  ('55840',
#   {'cell': '047-570-42-27',
#    'dob': '1950-04-19 11:43:47',
#    'email': 'milla.niva@example.com',
#    'gender': 'female',
#    'id': {'name': 'HETU', 'value': '650-654U'},
#    'location': {'city': 'muonio',
#     'postcode': 45314,
#     'state': 'kymenlaakso',
#     'street': '9077 satakennankatu'},
#    'login': {'md5': 'a892b93607475d24ef8f82ba0e201bb1',
#     'password': 'mayday',
#     'salt': 'ADvnk0pl',
#     'sha1': '5687472683265fc45f978158c7266e80e78eeb5f',
#     'sha256': 'b9c3b205085fc5fb5392e602eb4ea3157fb282929d2faf524855b2daed38d4d9',
#     'username': 'purpleladybug428'},
#    'name': {'first': 'milla', 'last': 'niva', 'title': 'miss'},
#    'nat': 'FI',
#    'phone': '07-645-427',
#    'picture': {'large': 'https://randomuser.me/api/portraits/women/36.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/women/36.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/women/36.jpg'},
#    'registered': '2015-03-23 22:13:53'}),
#  ('20966',
#   {'cell': '(755)-240-0451',
#    'dob': '1990-01-21 05:28:51',
#    'email': 'alexandra.robinson@example.com',
#    'gender': 'female',
#    'id': {'name': '', 'value': None},
#    'location': {'city': 'masterton',
#     'postcode': 52014,
#     'state': 'canterbury',
#     'street': '9464 carlton avenue'},
#    'login': {'md5': '6804652327b3c641ecddced73a230cab',
#     'password': 'hihihi',
#     'salt': 'WhH6oyJj',
#     'sha1': '2fcfd7623871ea5b8494ab865c1c60e08d9930b4',
#     'sha256': '29766faed4a527ab0296564ba9a16ccd97f7586bcdbad4d9d87dbc9e61204910',
#     'username': 'orangepanda253'},
#    'name': {'first': 'alexandra', 'last': 'robinson', 'title': 'ms'},
#    'nat': 'NZ',
#    'phone': '(177)-075-4528',
#    'picture': {'large': 'https://randomuser.me/api/portraits/women/7.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/women/7.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/women/7.jpg'},
#    'registered': '2016-03-14 04:14:08'}),
#  ('3017',
#   {'cell': '(179)-499-8004',
#    'dob': '1946-08-17 01:06:46',
#    'email': 'kelya.colin@example.com',
#    'gender': 'female',
#    'id': {'name': 'AVS', 'value': '756.QADT.UUQK.31'},
#    'location': {'city': 'vufflens-le-château',
#     'postcode': 5927,
#     'state': 'basel-stadt',
#     'street': '1997 rue denfert-rochereau'},
#    'login': {'md5': '48684a512c99f0171c1046f723e19222',
#     'password': '1226',
#     'salt': 'Aa3P8F2a',
#     'sha1': '515e8e8cc842fd3a09d211400b5760f737a70aae',
#     'sha256': '494d05f79bf75789132ddc9240b2f82f7f777c471b522b2256e25321bdc546b8',
#     'username': 'heavybird926'},
#    'name': {'first': 'kelya', 'last': 'colin', 'title': 'mademoiselle'},
#    'nat': 'CH',
#    'phone': '(905)-629-6449',
#    'picture': {'large': 'https://randomuser.me/api/portraits/women/70.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/women/70.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/women/70.jpg'},
#    'registered': '2015-05-14 18:58:18'}),
#  ('10528',
#   {'cell': '081-063-8737',
#    'dob': '1994-09-29 08:36:45',
#    'email': 'lisa.williams@example.com',
#    'gender': 'female',
#    'id': {'name': 'PPS', 'value': '1682843T'},
#    'location': {'city': 'laytown-bettystown-mornington',
#     'postcode': 43805,
#     'state': 'galway',
#     'street': '4880 station road'},
#    'login': {'md5': '4b2130f65614968bfeb62915e7caf86c',
#     'password': 'sealteam',
#     'salt': '4GGUM14l',
#     'sha1': '054ddea28505220ed620a2359fb2b49581235acd',
#     'sha256': 'dc586d8650dd436cb4f059211873733fd16c0e2540c35aa650830a4e27264e16',
#     'username': 'tinybear634'},
#    'name': {'first': 'lisa', 'last': 'williams', 'title': 'ms'},
#    'nat': 'IE',
#    'phone': '051-874-0512',
#    'picture': {'large': 'https://randomuser.me/api/portraits/women/47.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/women/47.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/women/47.jpg'},
#    'registered': '2012-06-24 12:06:18'}),
#  ('12871',
#   {'cell': '042-629-52-27',
#    'dob': '1986-04-27 18:46:01',
#    'email': 'ilona.salmela@example.com',
#    'gender': 'female',
#    'id': {'name': 'HETU', 'value': '386-4847'},
#    'location': {'city': 'sottunga',
#     'postcode': 21644,
#     'state': 'south karelia',
#     'street': '3397 hermiankatu'},
#    'login': {'md5': '5d90f71919932e78b5e32ff3699b7e26',
#     'password': 'decker',
#     'salt': 'k1LI9cBn',
#     'sha1': '21960972517448da7cf7d49cadd1cb6c869da104',
#     'sha256': 'c47a51dcdf98e009f05f616fd46d68e92bd2dbccb117fbd28fad15ca88e7f4d0',
#     'username': 'blackostrich722'},
#    'name': {'first': 'ilona', 'last': 'salmela', 'title': 'ms'},
#    'nat': 'FI',
#    'phone': '03-631-202',
#    'picture': {'large': 'https://randomuser.me/api/portraits/women/26.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/women/26.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/women/26.jpg'},
#    'registered': '2004-08-10 19:02:26'}),
#  ('42174',
#   {'cell': '(538)-076-0175',
#    'dob': '1993-12-25 11:53:24',
#    'email': 'chloe.watkins@example.com',
#    'gender': 'female',
#    'id': {'name': 'SSN', 'value': '950-11-2541'},
#    'location': {'city': 'lakeland',
#     'postcode': 56544,
#     'state': 'new hampshire',
#     'street': '3767 w 6th st'},
#    'login': {'md5': 'd80fcbd6fa0462d5475d9a60ea6730c2',
#     'password': 'barcelon',
#     'salt': 'D0r9jqyI',
#     'sha1': 'fdd77c57d7beaf810ad062ae12e9164771ecf3e5',
#     'sha256': '5c8e73be40e3891bb304094af6df2cbdb84a95859e2e3983ff589f2e57fb723b',
#     'username': 'smalltiger246'},
#    'name': {'first': 'chloe', 'last': 'watkins', 'title': 'mrs'},
#    'nat': 'US',
#    'phone': '(975)-729-7227',
#    'picture': {'large': 'https://randomuser.me/api/portraits/women/46.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/women/46.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/women/46.jpg'},
#    'registered': '2016-03-05 11:55:55'}),
#  ('50422',
#   {'cell': '(408)-627-0471',
#    'dob': '1980-06-04 06:18:27',
#    'email': 'mason.cole@example.com',
#    'gender': 'male',
#    'id': {'name': 'SSN', 'value': '358-89-4178'},
#    'location': {'city': 'amarillo',
#     'postcode': 38860,
#     'state': 'kansas',
#     'street': '8409 spring st'},
#    'login': {'md5': '48434adc9eece486f4f6487a83bdc7da',
#     'password': 'lansing',
#     'salt': 'z0YK152M',
#     'sha1': 'f04c0743f0ddbd1996ce69c1e23472b69a908f0f',
#     'sha256': '4a4607e52d44ed8225a9874dd8a4651d07ce0afe3a6c5b5fcb9f870928389f4e',
#     'username': 'smallbutterfly377'},
#    'name': {'first': 'mason', 'last': 'cole', 'title': 'mr'},
#    'nat': 'US',
#    'phone': '(397)-248-8996',
#    'picture': {'large': 'https://randomuser.me/api/portraits/men/5.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/men/5.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/men/5.jpg'},
#    'registered': '2010-08-25 04:36:37'}),
#  ('44701',
#   {'cell': '(560)-687-3875',
#    'dob': '1949-11-29 08:21:32',
#    'email': 'ann.montgomery@example.com',
#    'gender': 'female',
#    'id': {'name': 'SSN', 'value': '219-36-9452'},
#    'location': {'city': 'louisville',
#     'postcode': 96329,
#     'state': 'maine',
#     'street': '9979 cherry st'},
#    'login': {'md5': '527ff15b5e3bf7b946c8a4d0b23ff434',
#     'password': 'banshee',
#     'salt': 'x7YTojdg',
#     'sha1': '083f8c45f00cd92b5549c611904db0df432d3332',
#     'sha256': '5d0a692ba0809eae233ba557f00d6988f38928011fb6db12ee317c531d016834',
#     'username': 'blackdog848'},
#    'name': {'first': 'ann', 'last': 'montgomery', 'title': 'ms'},
#    'nat': 'US',
#    'phone': '(315)-745-1805',
#    'picture': {'large': 'https://randomuser.me/api/portraits/women/76.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/women/76.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/women/76.jpg'},
#    'registered': '2004-12-29 15:34:43'}),
#  ('68617',
#   {'cell': '(227)-161-7512',
#    'dob': '1985-02-08 23:50:47',
#    'email': 'debbie.bailey@example.com',
#    'gender': 'female',
#    'id': {'name': 'SSN', 'value': '203-13-8997'},
#    'location': {'city': 'costa mesa',
#     'postcode': 47927,
#     'state': 'wisconsin',
#     'street': '7063 avondale ave'},
#    'login': {'md5': 'bf4c2bbdd87b2f2f810a4546d7d79a31',
#     'password': 'media',
#     'salt': 'qWciLWsg',
#     'sha1': '39382eb494f2f29d7f11e54c24c3f18382fbd83a',
#     'sha256': 'd7bc6f042408c0a112c1198d04e3cebf95c8364f9e003195e52a81b306aa049c',
#     'username': 'organicbutterfly589'},
#    'name': {'first': 'debbie', 'last': 'bailey', 'title': 'mrs'},
#    'nat': 'US',
#    'phone': '(753)-918-0526',
#    'picture': {'large': 'https://randomuser.me/api/portraits/women/68.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/women/68.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/women/68.jpg'},
#    'registered': '2014-06-02 04:51:49'}),
#  ('39868',
#   {'cell': '0173-4163176',
#    'dob': '1984-06-27 11:00:44',
#    'email': 'svenja.zimmer@example.com',
#    'gender': 'female',
#    'id': {'name': '', 'value': None},
#    'location': {'city': 'märkisch-oderland',
#     'postcode': 90550,
#     'state': 'hessen',
#     'street': '6161 amselweg'},
#    'login': {'md5': 'e0aed993bf430a4779c9744994f08e45',
#     'password': 'titans',
#     'salt': 'atsigxgX',
#     'sha1': '513ada331bd4d229bba087de43a59124afd33f08',
#     'sha256': 'a11eb089a9f3fdc9ec69bf2b7d30be411c9582fc593bea8c801842d79b2f3a22',
#     'username': 'smallgorilla465'},
#    'name': {'first': 'svenja', 'last': 'zimmer', 'title': 'miss'},
#    'nat': 'DE',
#    'phone': '0963-8748452',
#    'picture': {'large': 'https://randomuser.me/api/portraits/women/74.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/women/74.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/women/74.jpg'},
#    'registered': '2014-03-07 06:43:46'}),
#  ('63653',
#   {'cell': '(427)-338-4384',
#    'dob': '1992-11-09 05:48:37',
#    'email': 'alicia.andre@example.com',
#    'gender': 'female',
#    'id': {'name': 'AVS', 'value': '756.BDCE.ONAY.48'},
#    'location': {'city': 'vulliens',
#     'postcode': 7648,
#     'state': 'valais',
#     'street': '6969 rue desaix'},
#    'login': {'md5': '3887412da9c5e332a3baefe33e7275df',
#     'password': 'sluttey',
#     'salt': 'DXFZQk8B',
#     'sha1': 'b6a3380cc48debba79c3fa2d83e1288f52b7aa40',
#     'sha256': '9e134905450766fdd2b7ed197d232e78b8866e931f31990c9536d6c92d9ae9ce',
#     'username': 'tinypeacock628'},
#    'name': {'first': 'alicia', 'last': 'andre', 'title': 'madame'},
#    'nat': 'CH',
#    'phone': '(318)-281-6855',
#    'picture': {'large': 'https://randomuser.me/api/portraits/women/93.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/women/93.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/women/93.jpg'},
#    'registered': '2002-08-28 23:10:21'}),
#  ('43256',
#   {'cell': '06-31-88-84-74',
#    'dob': '1989-09-15 01:24:29',
#    'email': 'alyssa.clement@example.com',
#    'gender': 'female',
#    'id': {'name': 'INSEE', 'value': '289861191892 67'},
#    'location': {'city': 'tourcoing',
#     'postcode': 58275,
#     'state': 'calvados',
#     'street': '9853 rue louis-garrand'},
#    'login': {'md5': 'df751f70e3bde2038e5359b1b6f32504',
#     'password': 'picasso',
#     'salt': 'ddKhuPMe',
#     'sha1': '6ced94d1bb351bf0ab7ebd69f2cc896a9bfa9294',
#     'sha256': 'a2f5cd31fbe7979fc44c52dcd07880138cade3c153ffe7a3b72fb49e7e3c92e3',
#     'username': 'ticklishgorilla918'},
#    'name': {'first': 'alyssa', 'last': 'clement', 'title': 'mrs'},
#    'nat': 'FR',
#    'phone': '03-97-59-43-25',
#    'picture': {'large': 'https://randomuser.me/api/portraits/women/41.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/women/41.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/women/41.jpg'},
#    'registered': '2008-09-03 14:41:24'}),
#  ('14530',
#   {'cell': '694-545-344',
#    'dob': '1963-12-20 09:17:41',
#    'email': 'benito.santiago@example.com',
#    'gender': 'male',
#    'id': {'name': 'DNI', 'value': '41658971-S'},
#    'location': {'city': 'oviedo',
#     'postcode': 86772,
#     'state': 'islas baleares',
#     'street': '9476 calle del pez'},
#    'login': {'md5': 'c5d2b86233d7e351650e087bf92d1709',
#     'password': 'mark',
#     'salt': 'IiihSB67',
#     'sha1': '27f3d38052adbbd3e60e86fa88fbfde4d34c7d47',
#     'sha256': '81f083b37c765a3a7107efd64f41e483c26f066c684154549f62f35aef73e399',
#     'username': 'silvermouse963'},
#    'name': {'first': 'benito', 'last': 'santiago', 'title': 'mr'},
#    'nat': 'ES',
#    'phone': '981-435-021',
#    'picture': {'large': 'https://randomuser.me/api/portraits/men/40.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/men/40.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/men/40.jpg'},
#    'registered': '2005-02-19 15:17:11'}),
#  ('31062',
#   {'cell': '(815)-138-8004',
#    'dob': '1967-01-29 07:04:04',
#    'email': 'latife.hummel@example.com',
#    'gender': 'female',
#    'id': {'name': 'BSN', 'value': '20611298'},
#    'location': {'city': 'stede broec',
#     'postcode': 38120,
#     'state': 'drenthe',
#     'street': '2131 lange nieuwstraat'},
#    'login': {'md5': '85616147965396646fa5fdff5a807fba',
#     'password': 'shelter',
#     'salt': '0V6D6oty',
#     'sha1': '191b4b2428d0726c984f36688e261d042abdb263',
#     'sha256': 'e1bf5e307434539e8631fad011d33781ade21e9a1b2e375b4b54bb09ca94113a',
#     'username': 'silverfish492'},
#    'name': {'first': 'latife', 'last': 'hummel', 'title': 'mrs'},
#    'nat': 'NL',
#    'phone': '(350)-720-8058',
#    'picture': {'large': 'https://randomuser.me/api/portraits/women/49.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/women/49.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/women/49.jpg'},
#    'registered': '2009-02-13 09:43:54'}),
#  ('49669',
#   {'cell': '(210)-497-6692',
#    'dob': '1966-08-25 02:47:32',
#    'email': 'begüm.demirbaş@example.com',
#    'gender': 'female',
#    'id': {'name': '', 'value': None},
#    'location': {'city': 'tekirdağ',
#     'postcode': 75627,
#     'state': 'karabük',
#     'street': '9157 atatürk sk'},
#    'login': {'md5': '7028c260bdcb69e27a917801784d656b',
#     'password': 'daniela',
#     'salt': 'puD9NmqA',
#     'sha1': 'd19bacc5d9117d5d0df670cf5a4515ed720d81b8',
#     'sha256': '77a131009d5bf6fb8421fab7b625a2e3655e3aeecfc332256bac746362de7448',
#     'username': 'ticklishbutterfly151'},
#    'name': {'first': 'begüm', 'last': 'demirbaş', 'title': 'miss'},
#    'nat': 'TR',
#    'phone': '(516)-919-5369',
#    'picture': {'large': 'https://randomuser.me/api/portraits/women/49.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/women/49.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/women/49.jpg'},
#    'registered': '2016-08-05 11:28:20'}),
#  ('5629',
#   {'cell': '0700-754-195',
#    'dob': '1994-08-07 07:45:21',
#    'email': 'brian.cruz@example.com',
#    'gender': 'male',
#    'id': {'name': 'NINO', 'value': 'PX 35 63 75 A'},
#    'location': {'city': 'kingston upon hull',
#     'postcode': 'B99 5TQ',
#     'state': 'shropshire',
#     'street': '6133 park lane'},
#    'login': {'md5': 'd99e2dd578ec6660a4907cab3f1acac1',
#     'password': 'bookie',
#     'salt': 'wQhwyGC9',
#     'sha1': '275c92db7c6070d7fcd34b4acff3d39aba929e19',
#     'sha256': '151bfd88d2fd17b0db3e0736783622b6875e18d70c4f3b59b6253afcba8b17ae',
#     'username': 'blackbutterfly646'},
#    'name': {'first': 'brian', 'last': 'cruz', 'title': 'mr'},
#    'nat': 'GB',
#    'phone': '015395 03561',
#    'picture': {'large': 'https://randomuser.me/api/portraits/men/12.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/men/12.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/men/12.jpg'},
#    'registered': '2009-07-04 19:29:05'}),
#  ('3616',
#   {'cell': '(357)-230-3035',
#    'dob': '1968-02-10 18:45:01',
#    'email': 'joseph.green@example.com',
#    'gender': 'male',
#    'id': {'name': '', 'value': None},
#    'location': {'city': 'wellington',
#     'postcode': 40959,
#     'state': 'southland',
#     'street': '3295 riverside drive'},
#    'login': {'md5': '5687a12c9aab521c4db48bc93c432947',
#     'password': 'meow',
#     'salt': '24R0NaWH',
#     'sha1': '7cf429cc9b8e77ecaa8c9d3dbd8edbe060a8b41f',
#     'sha256': '023f85b142cc9c1347f5e3136e75c212ccfda0807cc61ff6d487fad7c9c23f8f',
#     'username': 'beautifulfish800'},
#    'name': {'first': 'joseph', 'last': 'green', 'title': 'mr'},
#    'nat': 'NZ',
#    'phone': '(145)-954-5308',
#    'picture': {'large': 'https://randomuser.me/api/portraits/men/6.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/men/6.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/men/6.jpg'},
#    'registered': '2007-01-14 01:43:07'}),
#  ('54197',
#   {'cell': '(565)-076-6342',
#    'dob': '1960-08-23 08:11:39',
#    'email': 'aaron.fontai@example.com',
#    'gender': 'male',
#    'id': {'name': 'AVS', 'value': '756.CIYX.SHJT.77'},
#    'location': {'city': 'lonay',
#     'postcode': 1901,
#     'state': 'thurgau',
#     'street': '5313 rue des chartreux'},
#    'login': {'md5': '45d35bf42d41a9ccd874d2262a3bd66c',
#     'password': 'mariah',
#     'salt': 'hT06jcDH',
#     'sha1': '1de3f732fe92ab90b8b74b5fc48f523a7575ed93',
#     'sha256': 'eda47cd24348b7219bd5e3726723989c99dc7f579e0483d623f8e3982af8e3a9',
#     'username': 'orangemeercat511'},
#    'name': {'first': 'aaron', 'last': 'fontai', 'title': 'monsieur'},
#    'nat': 'CH',
#    'phone': '(865)-905-5336',
#    'picture': {'large': 'https://randomuser.me/api/portraits/men/29.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/men/29.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/men/29.jpg'},
#    'registered': '2010-05-31 03:21:56'}),
#  ('51564',
#   {'cell': '699-076-561',
#    'dob': '1956-12-18 15:55:18',
#    'email': 'guillermo.gallardo@example.com',
#    'gender': 'male',
#    'id': {'name': 'DNI', 'value': '04942565-E'},
#    'location': {'city': 'vitoria',
#     'postcode': 48543,
#     'state': 'comunidad valenciana',
#     'street': '4559 calle de arturo soria'},
#    'login': {'md5': '272ce96aed2c547612a08b8c061c0794',
#     'password': '666666',
#     'salt': 'JhqkQgrM',
#     'sha1': 'c9fb5ee9d0239c1cf62c3dd90ac4564ce271b745',
#     'sha256': '19729e372a8569ca2f228b31c98a4eae2c50dd45d3e2c0c3437edccf4131089e',
#     'username': 'goldenelephant636'},
#    'name': {'first': 'guillermo', 'last': 'gallardo', 'title': 'mr'},
#    'nat': 'ES',
#    'phone': '936-220-076',
#    'picture': {'large': 'https://randomuser.me/api/portraits/men/99.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/men/99.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/men/99.jpg'},
#    'registered': '2005-04-01 16:55:11'}),
#  ('59336',
#   {'cell': '99945331',
#    'dob': '1977-05-26 07:14:37',
#    'email': 'ella.johansen@example.com',
#    'gender': 'female',
#    'id': {'name': 'CPR', 'value': '496402-6500'},
#    'location': {'city': 'amager',
#     'postcode': 53933,
#     'state': 'sjælland',
#     'street': '7094 bjergvej'},
#    'login': {'md5': '77915ef640e4cabfe0c144a77e49dae1',
#     'password': 'nian',
#     'salt': 'JjfNseag',
#     'sha1': 'd91e4dc27183a894f0e32f0ef6e2a3fbeee2c7c6',
#     'sha256': '2639d9c858aee668561a18aeee416bdfaffddddac02dfcaf79c7e300ccf80c10',
#     'username': 'goldenlion147'},
#    'name': {'first': 'ella', 'last': 'johansen', 'title': 'mrs'},
#    'nat': 'DK',
#    'phone': '26530544',
#    'picture': {'large': 'https://randomuser.me/api/portraits/women/68.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/women/68.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/women/68.jpg'},
#    'registered': '2013-08-05 04:06:39'}),
#  ('9400',
#   {'cell': '0433-483-941',
#    'dob': '1987-05-29 23:47:42',
#    'email': 'joyce.warren@example.com',
#    'gender': 'female',
#    'id': {'name': 'TFN', 'value': '392831754'},
#    'location': {'city': 'geelong',
#     'postcode': 4286,
#     'state': 'western australia',
#     'street': '8516 cherry st'},
#    'login': {'md5': '071f82228bf95fd95075b02b51293c5e',
#     'password': 'melody',
#     'salt': 'I3abVhD5',
#     'sha1': 'e07689a946c249697df20fb104ef3b7d55304e0f',
#     'sha256': '38c45dfdade3a07bdd9424cf077384fba9a0f235733a9d1f84a111e1843df277',
#     'username': 'crazydog350'},
#    'name': {'first': 'joyce', 'last': 'warren', 'title': 'ms'},
#    'nat': 'AU',
#    'phone': '05-2069-5512',
#    'picture': {'large': 'https://randomuser.me/api/portraits/women/8.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/women/8.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/women/8.jpg'},
#    'registered': '2013-09-22 13:01:52'}),
#  ('35651',
#   {'cell': '0995-544-9254',
#    'dob': '1950-08-06 08:01:28',
#    'email': 'نيما.كامياران@example.com',
#    'gender': 'male',
#    'id': {'name': '', 'value': None},
#    'location': {'city': 'قرچک',
#     'postcode': 32852,
#     'state': 'کرمانشاه',
#     'street': '4735 شهید علی باستانی'},
#    'login': {'md5': '616da4992034bc0d3323ab6fe0305e18',
#     'password': 'attack',
#     'salt': '2iAdavMv',
#     'sha1': '899263cfb840114c91208f96e3a8eeeea932fc98',
#     'sha256': '8de16853930213513be3146f58ef5704c7a6918d60575829ce9d38ab53d37e31',
#     'username': 'heavygorilla598'},
#    'name': {'first': 'نيما', 'last': 'كامياران', 'title': 'mr'},
#    'nat': 'IR',
#    'phone': '008-58587766',
#    'picture': {'large': 'https://randomuser.me/api/portraits/men/21.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/men/21.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/men/21.jpg'},
#    'registered': '2014-02-21 00:05:17'}),
#  ('57064',
#   {'cell': '0177-0789538',
#    'dob': '1958-04-15 11:14:38',
#    'email': 'tabea.roth@example.com',
#    'gender': 'female',
#    'id': {'name': '', 'value': None},
#    'location': {'city': 'teltow-fläming',
#     'postcode': 92880,
#     'state': 'rheinland-pfalz',
#     'street': '4791 goethestraße'},
#    'login': {'md5': 'e8e3c3f72b83a5c7ca374b74bdf71e24',
#     'password': 'things',
#     'salt': 'l35UdQfc',
#     'sha1': 'c98584a7cb5f45281cce0b85254875c158fafe14',
#     'sha256': '0b256f3ebf336d5f8fc7b25cca15daa97826313af5b21e2032e7d150e4db849e',
#     'username': 'lazybear304'},
#    'name': {'first': 'tabea', 'last': 'roth', 'title': 'ms'},
#    'nat': 'DE',
#    'phone': '0789-2213824',
#    'picture': {'large': 'https://randomuser.me/api/portraits/women/68.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/women/68.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/women/68.jpg'},
#    'registered': '2009-10-11 21:54:37'}),
#  ('53857',
#   {'cell': '0970-145-8517',
#    'dob': '1946-10-27 08:23:30',
#    'email': 'اميرعلي.یاسمی@example.com',
#    'gender': 'male',
#    'id': {'name': '', 'value': None},
#    'location': {'city': 'شهریار',
#     'postcode': 47668,
#     'state': 'لرستان',
#     'street': '9841 مصطفی خمینی'},
#    'login': {'md5': '6bbcd50d39b97227ffcda9f1764ce20f',
#     'password': 'buzz',
#     'salt': 't4NZEJgG',
#     'sha1': 'c2603b3be626a57a0aff36b918f306f44f7abd8a',
#     'sha256': '07280ce4bfe8a3cd4ff6fde6f4c1288dc9758703662103e246012a15a16d2d38',
#     'username': 'blackpeacock755'},
#    'name': {'first': 'اميرعلي', 'last': 'یاسمی', 'title': 'mr'},
#    'nat': 'IR',
#    'phone': '005-24557980',
#    'picture': {'large': 'https://randomuser.me/api/portraits/men/60.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/men/60.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/men/60.jpg'},
#    'registered': '2007-05-03 05:49:30'}),
#  ('38544',
#   {'cell': '949-745-2265',
#    'dob': '1958-09-18 04:31:41',
#    'email': 'laurie.martin@example.com',
#    'gender': 'female',
#    'id': {'name': '', 'value': None},
#    'location': {'city': 'lumsden',
#     'postcode': 99083,
#     'state': 'saskatchewan',
#     'street': '7217 victoria ave'},
#    'login': {'md5': 'db7a90ae9b9ef662bd5f51a0b107647a',
#     'password': 'soulmate',
#     'salt': 'FpjJ9nk5',
#     'sha1': 'b21a682133a1b8e8324bbd025023d0643bc44190',
#     'sha256': '6d4622a3f3cf99fa90e7a50bfeb9e88c4ee9c01dfbcd75355058193ebbc10335',
#     'username': 'whitemouse971'},
#    'name': {'first': 'laurie', 'last': 'martin', 'title': 'miss'},
#    'nat': 'CA',
#    'phone': '465-220-0723',
#    'picture': {'large': 'https://randomuser.me/api/portraits/women/49.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/women/49.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/women/49.jpg'},
#    'registered': '2007-07-01 13:42:20'}),
#  ('9040',
#   {'cell': '(03) 6958-1806',
#    'dob': '1960-10-26 13:35:41',
#    'email': 'arnaldo.souza@example.com',
#    'gender': 'male',
#    'id': {'name': '', 'value': None},
#    'location': {'city': 'gravataí',
#     'postcode': 25390,
#     'state': 'pará',
#     'street': '5710 rua treze '},
#    'login': {'md5': '5b7ca1db21fa2d5d9ea2b04475994657',
#     'password': 'vvvv',
#     'salt': 'MCtjNeB3',
#     'sha1': 'bfb41f9b77e937fd6a922a41052b32218d26a934',
#     'sha256': 'de77910a3885228fd48d7ba7bfab38d24049d4c737d0acebc7a1859f6cc483a3',
#     'username': 'orangeleopard721'},
#    'name': {'first': 'arnaldo', 'last': 'souza', 'title': 'mr'},
#    'nat': 'BR',
#    'phone': '(37) 5633-6101',
#    'picture': {'large': 'https://randomuser.me/api/portraits/men/86.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/men/86.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/men/86.jpg'},
#    'registered': '2013-12-17 11:20:45'}),
#  ('57475',
#   {'cell': '(802)-814-9612',
#    'dob': '1971-03-02 19:29:23',
#    'email': 'tracy.sutton@example.com',
#    'gender': 'female',
#    'id': {'name': 'SSN', 'value': '393-14-9084'},
#    'location': {'city': 'garden grove',
#     'postcode': 19694,
#     'state': 'louisiana',
#     'street': '8359 woodland st'},
#    'login': {'md5': '9413b36efdc8a761c450342eaa1f0774',
#     'password': 'larry',
#     'salt': 'wu4LrgHx',
#     'sha1': 'c35e90143366f5f9511e0b4a28b10d7abc5c7f92',
#     'sha256': '9f950793b2b24400a8942412d05d4fc96bc8230eb5b3ecdd26c0144f8b7c5536',
#     'username': 'tinybird193'},
#    'name': {'first': 'tracy', 'last': 'sutton', 'title': 'miss'},
#    'nat': 'US',
#    'phone': '(180)-779-3231',
#    'picture': {'large': 'https://randomuser.me/api/portraits/women/75.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/women/75.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/women/75.jpg'},
#    'registered': '2004-05-27 20:01:23'}),
#  ('46352',
#   {'cell': '444-096-6032',
#    'dob': '1985-07-29 18:25:36',
#    'email': 'gabriel.macdonald@example.com',
#    'gender': 'male',
#    'id': {'name': '', 'value': None},
#    'location': {'city': 'odessa',
#     'postcode': 61326,
#     'state': 'yukon',
#     'street': '4115 arctic way'},
#    'login': {'md5': '2ef8c0b63bda04be8728c664d918b066',
#     'password': 'kerstin',
#     'salt': 'ZjxNyCxN',
#     'sha1': 'be06c34959ad7109e9d6692ec393c8ddf2be1750',
#     'sha256': '38b6e910a2af35c55fc4b44b2fd2c2a4a0ba1f5b0c673e7b2dca239b8e504f15',
#     'username': 'purpleelephant569'},
#    'name': {'first': 'gabriel', 'last': 'macdonald', 'title': 'mr'},
#    'nat': 'CA',
#    'phone': '744-947-8934',
#    'picture': {'large': 'https://randomuser.me/api/portraits/men/73.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/men/73.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/men/73.jpg'},
#    'registered': '2003-07-03 01:00:59'})]

# %%
r.keys()
# Out:
# dict_keys(['results', 'info'])
